# %%
from fastmcp.client import Client
from rich.pretty import pprint

client = Client(transport='http://localhost:8000/sse')
async with client:
	tools = await client.list_tools()
	pprint(tools)
# Out:
# [
# │   Tool(
# │   │   name='addition_tool',
# │   │   title=None,
# │   │   description='Adds two numbers together.',
# │   │   inputSchema={
# │   │   │   'properties': {'a': {'type': 'number'}, 'b': {'type': 'number'}},
# │   │   │   'required': ['a', 'b'],
# │   │   │   'type': 'object'
# │   │   },
# │   │   outputSchema={'additionalProperties': True, 'type': 'object'},
# │   │   icons=None,
# │   │   annotations=None,
# │   │   meta={'_fastmcp': {'tags': []}},
# │   │   execution=None
# │   ),
# │   Tool(
# │   │   name='web_search_tool',
# │   │   title=None,
# │   │   description='Search the web for a query and return results.',
# │   │   inputSchema={
# │   │   │   'properties': {
# │   │   │   │   'url': {'type': 'string'},
# │   │   │   │   'user_agent': {'type': 'string'},
# │   │   │   │   'max_chars': {'default': 1000, 'type': 'integer'},
# │   │   │   │   'start_index': {'default': 0, 'type': 'integer'}
# │   │   │   },
# │   │   │   'required': ['url', 'user_agent'],
# │   │   │   'type': 'object'
# │   │   },
# │   │   outputSchema={
# │   │   │   'properties': {'result': {'type': 'string'}},
# │   │   │   'required': ['result'],
# │   │   │   'type': 'object',
# │   │   │   'x-fastmcp-wrap-result': True
# │   │   },
# │   │   icons=None,
# │   │   annotations=None,
# │   │   meta={'_fastmcp': {'tags': []}},
# │   │   execution=None
# │   )
# ]

# %%
async with client:
    res = await client.call_tool('addition_tool', {'a': 5, 'b': 10})
    pprint(res)
# Out:
# CallToolResult(
# │   content=[TextContent(type='text', text='{"result":15.0}', annotations=None, meta=None)],
# │   structured_content={'result': 15.0},
# │   meta=None,
# │   data={'result': 15.0},
# │   is_error=False
# )

# %%
from agent_framework.tools.mcp_tool import MCPTool, MCPClient
from rich.pretty import pprint

client = MCPClient()
await client.connect_sse('http://localhost:8000/sse')
async with client:
    res = await client.call_tool('addition_tool', {'a': 5, 'b': 10})
    pprint(res)

    res_search = await client.call_tool('web_search_tool', {'url': 'https://ai-sdk.dev/docs/ai-sdk-ui/chatbot',
                                                            'user_agent': 'windows',
                                                            })
    pprint(res_search)
# Out:
# CallToolResult(
# │   meta=None,
# │   content=[TextContent(type='text', text='{"result":15.0}', annotations=None, meta=None)],
# │   structuredContent={'result': 15.0},
# │   isError=False
# )
# CallToolResult(
# │   meta=None,
# │   content=[
# │   │   TextContent(
# │   │   │   type='text',
# │   │   │   text="The `useChat` hook makes it effortless to create a conversational user interface for your chatbot application. It enables the streaming of chat messages from your AI provider, manages the chat state, and updates the UI automatically as new messages arrive.\n\nTo summarize, the `useChat` hook provides the following features:\n\n* **Message Streaming**: All the messages from the AI provider are streamed to the chat UI in real-time.\n* **Managed States**: The hook manages the states for input, messages, status, error and more for you.\n* **Seamless Integration**: Easily integrate your chat AI into any design or layout with minimal effort.\n\nIn this guide, you will learn how to use the `useChat` hook to create a chatbot application with real-time message streaming.\nCheck out our [chatbot with tools guide](/docs/ai-sdk-ui/chatbot-tool-usage) to learn how to use tools in your chatbot.\nLet's start with the following example first.\n\n## [Example](#example)\n\n```\n'use client';\n\n\n\nimport { useChat } from",
# │   │   │   annotations=None,
# │   │   │   meta=None
# │   │   )
# │   ],
# │   structuredContent={
# │   │   'result': "The `useChat` hook makes it effortless to create a conversational user interface for your chatbot application. It enables the streaming of chat messages from your AI provider, manages the chat state, and updates the UI automatically as new messages arrive.\n\nTo summarize, the `useChat` hook provides the following features:\n\n* **Message Streaming**: All the messages from the AI provider are streamed to the chat UI in real-time.\n* **Managed States**: The hook manages the states for input, messages, status, error and more for you.\n* **Seamless Integration**: Easily integrate your chat AI into any design or layout with minimal effort.\n\nIn this guide, you will learn how to use the `useChat` hook to create a chatbot application with real-time message streaming.\nCheck out our [chatbot with tools guide](/docs/ai-sdk-ui/chatbot-tool-usage) to learn how to use tools in your chatbot.\nLet's start with the following example first.\n\n## [Example](#example)\n\n```\n'use client';\n\n\n\nimport { useChat } from"
# │   },
# │   isError=False
# )
