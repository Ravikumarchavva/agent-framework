# %%
from agent_framework.agents.base_agent import BaseAgent
from agent_framework.memory.base_memory import BaseMemory
from agent_framework.model_clients.base_client import BaseModelClient
from agent_framework.tools.base_tool import BaseTool

memory = BaseMemory()
model_client = BaseModelClient()
tool = BaseTool()
agent = BaseAgent(memory=memory, model_client=model_client, tools=[tool])
print(agent)  # Just to demonstrate usage
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 from agent_framework.model_clients.base_client import BaseModelClient
#       4 from agent_framework.tools.base_tool import BaseTool
# ----> 6 memory = BaseMemory()
#       7 model_client = BaseModelClient()
#       8 tool = BaseTool()
#
# TypeError: Can't instantiate abstract class BaseMemory without an implementation for abstract methods 'retrieve', 'store'
