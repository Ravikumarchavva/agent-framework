# %%
nums = [[0,0,0,0], [0,0,0,0]]
print(nums)
# Out:
# [[0, 0, 0, 0], [0, 0, 0, 0]]

# %%
nums[0]
# Out:
# [0, 0, 0, 0]

# %%
len(nums)
# Out:
# 2

# %%
[[0]*4]*2
# Out:
# [[0, 0, 0, 0], [0, 0, 0, 0]]

# %%
for row in nums:
    for col in row:
        print(col)
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
